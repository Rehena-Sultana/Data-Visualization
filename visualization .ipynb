# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('fivethirtyeight')

# %%
df=pd.read_csv('tips.csv')
df[:3]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# Normally, when we try to solve real-time data problems, we have numerical and categorical data. In this analysis, I will try to showcase the possible ways of representing numerical and categorical plots.

# %% [markdown]
# # **Scatter plot for numerical values:**

# %% [markdown]
# we can implement scatterplot in 2 ways using seaborn:
#    * 1) relplot
#    * 2)scatterplot

# %%
sns.relplot(x='total_bill',y='tip',data=df)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=df)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='sex',data=df)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='sex',size='size',data=df)

# %% [markdown]
# # **scatter plot for categorical column**

# %% [markdown]
# * stripplot
# * swarmplot

# %%
sns.catplot(x='sex',y='tip',kind='strip',jitter=0,data=df)

# %%
#swarm plot
sns.catplot(x='sex',y='tip',kind='swarm',data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='sex',y='tip',kind='swarm',hue='smoker',data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='sex',y='tip',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# A swarmplot differs from a stripplot in that they both provide the same information, but a swarmplot also includes the distribution concept.

# %% [markdown]
# # **Jointplot**<br>
# gives us the scatter plot and histogram as well.
#
# * scatterplot(itself)
# * regplot
# * hexbin plot
# * kdeplot

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
#regression plot
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')

# %%
#hexbin plot
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')#in this plot dark colr hexagonal represents high frequency

# %%
#kde plot
sns.jointplot(x='total_bill',y='tip',data=df,kind='kde')

# %% [markdown]
# # **Pairplot**<br>
# gives us the multiple pairwise bivariate distribution

# %%
sns.pairplot(df,hue='sex')

# %% [markdown]
# # **Boxplot**

# %% [markdown]
# Box plot gives us a summary of data distribution with 5 tuples such as-minimum,1st quartile,median,3rd quartile,maximun.
#
# * Q1= 25% quartile
# * Q3= 75% QUARTILE
#
# * IQR(Inter Quartile Range)=Q3-Q1
#
# * minimun=Q1-1.5*IQR
#
# * maximum=Q3+1.5*IQR
#
# * The values less than the minimun and the values greater than the maximun are called outliers.

# %%
sns.boxplot(df['tip'])
# Out:
# <Axes: >

# %%
sns.catplot(x='day',y='tip',data=df,kind='box')

# %% [markdown]
# # **PDF(Probability Density Function)**

# %%
import scipy.stats as stats
df.sort_values(by=['tip'], inplace=True)
df_mean = np.mean(df["tip"])
df_std = np.std(df["tip"])
pdf = stats.norm.pdf(df["tip"], df_mean, df_std)

plt.plot(df["tip"], pdf)

# %%
sns.distplot(df['tip'])
# Out:
# <ipython-input-64-3f4491b3d128>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # Violinplot
# * gives us the boxplot and data distribution with KDE

# %%
plt.figure(figsize=(10,5))
sns.violinplot(df['tip'])
#plt.legend()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,7))
sns.violinplot(x='day',y='tip',split=True,hue='sex',data=df)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # **Barpot**

# %%
sns.barplot(x='sex',y='tip',estimator=np.mean,data=df)#estimator could me mean.median,variance(var),standard deviation(std)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# # **`Histogram`**<br>

# %%
plt.hist(df['tip'])
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # **Distplot**
# * gives us the distribution of data
# <br>
# distplot is a combination of 3 plot namely-
# * histogram
# * KDE(PDF)
# * rudge-like hist but represented by vertical bar, high density means many observations present

# %%
sns.distplot(df['tip'],rug=True)
# Out:
# <ipython-input-69-a065a2c3ba5c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'],rug=True)
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # **Pie chart**

# %%
df[:3]
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1
# 236       12.60  1.0    Male    Yes  Sat  Dinner     2
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2

# %%
def label_function(val):
    return f'{val / 100 * len(df):.0f}\n{val:.0f}%'

df.groupby('sex')['sex'].size().plot(kind='pie',autopct=label_function,textprops={'fontsize': 20},colors=['b','g'])

plt.show()

# %% [markdown]
# # **Countplot**

# %% [markdown]
# *

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # **Heatmaps**<br>
# representing the relationship among the numerical values

# %%
sns.heatmap(df.corr(),annot=True,linewidths=0.2)
# Out:
# <ipython-input-73-168a2aaf48fa>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,linewidths=0.2)
# <Axes: >

# %% [markdown]
# # **Clusterplot**<br>
# it gives the group of data based on relationship among the variables.

# %%
sns.clustermap(df.corr(),annot=True,row_cluster=False)
# Out:
# <ipython-input-74-eee33e8ac580>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.clustermap(df.corr(),annot=True,row_cluster=False)
